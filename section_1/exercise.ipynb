# %% [markdown]
# <a href="https://colab.research.google.com/github/TXXXW-WQ/Android-tutorial/blob/master/section_1/exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 演習
# Pythonを学ぶ前に、Google Colaboratoryの使い方に慣れておきましょう。
# このノートブックで、以下のセルの操作を行ってみましょう。
#
# * コードセルの作成
# * コードセルにPythonのコードを記述し、「Hello World!」と表示
# * コードセルに足し算のコードを記述し、結果を表示
# * テキストセルの作成
# * テキストセルに文章を記述
# * テキストセルで文章を改行
# * テキストセルにリストを記述
# * セルの上下の入れ替え
# * セルの消去

# %%
print("Hello world")
# Out:
# Hello world

# %%
a = 2
b = 10
print(a + b)
# Out:
# 12
